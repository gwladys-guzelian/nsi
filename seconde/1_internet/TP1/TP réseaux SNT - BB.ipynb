# %% [markdown]
# ## Connaître les paramètres réseau de son ordinateur

# %% [markdown]
# ---
#
# ## 1. Connaître sa propre adresse IP et celle de son DNS

# %% [markdown]
# !!! note À faire
#
# Commencez par ouvrir l’invite de commandes de Windows. Pour cela :
#
# 1. Dans le menu *Démarrer*, tapez `cmd` ou « invite de commandes » sans appuyer sur la touche Entrée.
# 2. Puis cliquez sur l’icône Invite de commandes (ou `cmd`) qui ressemble à l'image ci-dessous :
#
# ![invie de commandes](https://info-mounier.fr/snt/internet/data/invite_de_commandes.png)
#
#
#
# Répondez aux questions qui suivent.
# !!!

# %% [markdown]
# !!! question 💻✍️ Question 1
# Tapez la commande `ipconfig` dans l’invite de commande puis validez en tapant Entrée (vous devriez obtenir un écran qui ressemble à celui ci-dessous).
#
# ![exemple de réponse de ipconfig](https://info-mounier.fr/snt/internet/data/ipconfig.png)
#
# Trouvez dans les lignes qui s'affichent sur votre écran, l'adresse IP (version 4) de votre ordinateur.
# !!!

# %% [raw]
# adresse IP :

# %% [markdown]
# !!! question ✍️ Question 2
# Les ordinateurs d'un même réseau local ont des adresses IP qui commencent par les mêmes chiffres. Comparez votre adresse IP avec celles des ordinateurs de vos voisins. Que constatez-vous ?
# !!!

# %% [raw]
# votre réponse :

# %% [markdown]
# !!! question 💻✍️Question 3
# Tapez maintenant la commande `ipconfig /all` dans l'invite de commande puis validez avec la touche Entrée.
#
# Cherchez dans les lignes qui apparaissent celle s'intitulant "Serveurs DNS" et **notez** l'adresse (ou les adresses) IP de votre (vos) serveurs DNS.
# !!!

# %% [raw]
# votre réponse :

# %% [markdown]
# ---
#
# ## 2. Connaître l'adresse IP du destinataire

# %% [markdown]
# !!! info DNS : rappel de cours
# Comme il n'est pas simple pour un humain de retenir tout un tas d'adresses IP, on utilise plutôt des adresses symboliques. Ainsi, si on veut se connecter au site www.lemonde.fr, il suffit de taper www.lemonde.fr dans la barre d'URL du navigateur et on n'a pas besoin de connaître l'adresse IP du serveur qui héberge ce site.
#
# En effet, c'est le serveur DNS qui connaît les correspondances entre adresses IP et adresses symboliques et qui nous dira quelle est l'adresse IP du serveur hébergeant le site en question.
# !!!

# %% [markdown]
# !!! question 💻✍️ Question 4
# Pour tester si une machine est joignable sur le réseau Internet, on peut utiliser la commande ping. Tapez la commande ``ping www.lemonde.fr`` dans l'invite de commandes et **notez** l'adresse IP de la machine www.lemonde.fr qui apparaît dans les informations affichées.
# !!!

# %% [raw]
# votre réponse :

# %% [markdown]
# ---
#
# ## 3. Connaître le chemin parcouru dans le réseau

# %% [markdown]
# Pour connaître l'intinéraire suivi par les paquets entre l'expéditeur et le destinataire (les adresses IP et les noms des routeurs qui ont permis l’acheminement des paquets) on peut utiliser la commande `tracert`.

# %% [markdown]
# !!! question 💻✍️Question 5
# Tapez la commande `tracert www.lemonde.fr` (et validez avec Entrée).
# Vérifiez que la dernière ligne correspond bien à www.lemonde.fr.
# Par combien de routeurs les paquets sont-ils passés pour atteindre la machine www.lemonde.fr ?
# !!!

# %% [raw]
# votre réponse :

# %% [markdown]
# ---
#
#
# !!! tip FIN DU TP
# N'oubliez pas d'enregistrer le travail et de le rendre en cliquant sur l'enveloppe en haut à droite.
# !!!

# %% [markdown]
# d'après le [cours de SNT des enseignants du lycée Emmanuel Mounier à Angers.](https://info-mounier.fr/snt/internet/protocole-tcp-ip.php#partie-3-:-dns)
